# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.8.0-cp39-cp39-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 7.6/7.6 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\pstudy\pythonproject\venv\lib\site-packages (from matplotlib) (23.1)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: numpy<2,>=1.21 in c:\pstudy\pythonproject\venv\lib\site-packages (from matplotlib) (1.25.2)
# Collecting pillow>=6.2.0
#   Downloading Pillow-10.0.1-cp39-cp39-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 1.3 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.42.1-cp39-cp39-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 2.5 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp39-cp39-win_amd64.whl (56 kB)
#      -------------------------------------- 56.2/56.2 kB 999.2 kB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.1-py3-none-any.whl (103 kB)
#      -------------------------------------- 103.1/103.1 kB 1.2 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.1-cp39-cp39-win_amd64.whl (435 kB)
#      -------------------------------------- 436.0/436.0 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\pstudy\pythonproject\venv\lib\site-packages (from matplotlib) (2.8.2)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\pstudy\pythonproject\venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.16.2)
# Requirement already satisfied: six>=1.5 in c:\pstudy\pythonproject\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.11.0 fonttools-4.42.1 importlib-resources-6.0.1 kiwisolver-1.4.5 matplotlib-3.8.0 pillow-10.0.1 pyparsing-3.1.1
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
#Figure 객체 생성
figure= plt.figure()

axes = figure. add_subplot(111) #행 열 번호 
x= ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June']
y= [1200, 800, 500, 400, 700, 800]
axes. plot(x, y, linestyle= '--', marker='^', color = 'red') 
plt.show()
